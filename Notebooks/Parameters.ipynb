# %%
datasets = [
    {
        "file_name" : "orders"
    },
    {
        "file_name" : "customers"
    },
    {
        "file_name" : "products"
    },
]

# %% [markdown]
# Let's use this as our input

# %%
dbutils.jobs.taskValues.set("output_datasets", datasets)
